# %% [markdown]
# ## Загрузка нашей модели и импорт необходимых библиотек

# %%
from ultralytics import YOLO
from api import send_car_number
import cv2
from IPython.display import Image, display
model = YOLO(r'C:\TTTT\lessonsplatedetection\main\runs\detect\yolo\weights\best.pt')

# %% [markdown]
# ## Я предоставил тест кейсы для моей модели, также провел небольшой анализ тест кейсов
# #### Модель хорошо справилась со свой задачей, в большинстве тест кейсов номер определен почти правильно. Несмотря на грязь на номерх и плохое освещение, на некоторых тест кейсых, считывание символом происходит на достойной уровне.
# #### К сожелению, на фотографиях с двумя авто модель определяет номер только одного из них.

# %% [markdown]
# ## Тест кейс 1

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\1_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 2 lesson plates, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: B241YT 35

# %% [markdown]
# ## Тест кейс 2

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\2_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 1 lesson plate, 72.1ms
# Speed: 1.0ms preprocess, 72.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: P900AP 35

# %% [markdown]
# ## Тест кейс 3

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\3_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 1 lesson plate, 60.1ms
# Speed: 1.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: Y 133YCE

# %% [markdown]
# ## Тест кейс 4

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\4_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 448x640 1 lesson plate, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 448, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: C483XY197

# %% [markdown]
# ## Тест кейс 5

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\5_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 512x640 1 lesson plate, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 1.0ms postprocess per image at shape (1, 3, 512, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: M63AMX177

# %% [markdown]
# ## Тест кейс 6

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\6_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 1 lesson plate, 64.1ms
# Speed: 1.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: Y 508AY35

# %% [markdown]
# ## Тест кейс 7

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\7_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 2 lesson plates, 73.5ms
# Speed: 1.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: 056AH35

# %% [markdown]
# ## Тест кейс 8

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\8_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 2 lesson plates, 63.1ms
# Speed: 1.0ms preprocess, 63.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: A184XE138

# %% [markdown]
# ## Тест кейс 9

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\9_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 1 lesson plate, 60.1ms
# Speed: 1.0ms preprocess, 60.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: Y679YC 35

# %% [markdown]
# ## Тест кейс 10

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\10_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 2 lesson plates, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: B518TT352

# %% [markdown]
# ## Тест кейс 11

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\11_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 2 lesson plates, 74.1ms
# Speed: 2.0ms preprocess, 74.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: BO45TP35

# %% [markdown]
# ## Тест кейс 12

# %%
result = send_car_number(r'C:\TTTT\lessonsplatedetection\testcases\Test cases\12_test_case.jpg')
_,ret = cv2.imencode('.jpg', result[1]) 
display(Image(data=ret))
print(f'Предпологаемый номер изображенный на изображение: {result[0][-1][-1]}')
# Out:
# 0: 480x640 1 lesson plate, 85.1ms
# Speed: 1.0ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
# Using CPU. Note: This module is much faster with a GPU.
# Предпологаемый номер изображенный на изображение: PB131PA35
